# %%
import numpy as np
import pandas as pd
import pypsa
import matplotlib.pyplot as plt
from unyt import MWh, kWh

# %% [markdown]
# ## PyPSA Network

# %% [markdown]
# Step 1: Create the network and timesteps (snapshots)

# %%
n = pypsa.Network(name='Armourdale')

N_days=365
N_hours=24

index = pd.date_range(start="2018-01-01", 
                      periods=N_days*N_hours, 
                      freq='h')

n.set_snapshots(index)

# %% [markdown]
# Step 2: Add energy carriers

# %%
n.add(class_name="Carrier", name="grid")
n.add(class_name="Carrier", name="solar")
n.add(class_name="Carrier", name="battery")
n.add(class_name="Carrier", name='net metering')

# %% [markdown]
# Step 3: Add buses

# %%
bus_name = 'Residential'
bus_names = ['Residential','CommunitySolar']
for bus in bus_names:
      n.add(class_name="Bus",
            name=bus,
            carrier='AC')

# %% [markdown]
# Step 4: Add lines connecting the buses

# %%
n.add(class_name='Line',
      name=f"CommSol-Res",
      bus0="CommunitySolar",
      bus1="Residential",
      )

# %% [markdown]
# Step 5: Add load

# %%
load = pd.read_csv("../data/timeseries/residential_elec_load_rescaled.csv", parse_dates=True, index_col='timestamp')

# %%
load_resampled = load.loc['2018'].resample('h').mean().sum(axis=1)
load_resampled = load_resampled / 1e3  # kW --> MW

# %%
n.add(
    class_name="Load",
    name=f"Load {bus_name}",
    bus=bus_name,
    p_set=load_resampled
)

# %% [markdown]
# Step 6: Add weather data

# %%
weather = pd.read_csv("../data/timeseries/weather_year.csv", parse_dates=True, index_col=0)
weather.head()
# Out:
#                                date_time  temp_db  rel_humidity  wind_speed  \
# 2018-01-01 00:00:00  2005-01-01 01:00:00      8.0            61         5.7
# 2018-01-01 01:00:00  2005-01-01 02:00:00      8.0            57         5.1
# 2018-01-01 02:00:00  2005-01-01 03:00:00      8.0            57         5.1
# 2018-01-01 03:00:00  2005-01-01 04:00:00      7.0            56         6.2
# 2018-01-01 04:00:00  2005-01-01 05:00:00      7.0            56         5.1
#
#                      wind_direction  ghi  dni  dhi
# 2018-01-01 00:00:00              80    0    0    0
# 2018-01-01 01:00:00              90    0    0    0
# 2018-01-01 02:00:00              90    0    0    0
# 2018-01-01 03:00:00              80    0    0    0
# 2018-01-01 04:00:00              90    0    0    0

# %%
# normalize GHI
ghi = weather['ghi'] / weather['ghi'].max()

# %% [markdown]
# Step 4: Upload cost data

# %%
costs = pd.read_csv("../data/technology_costs.csv", index_col='technology')

# %%
costs *= 1e3  # convert /kW to /MW
costs
# Out:
#                                 Fixed O&M           OCC
# technology
# DistributedWind              35912.100000  5.678577e+06
# ResPV                        28108.825392  2.630889e+06
# Residential Battery Storage  78943.789878  3.157752e+06

# %%
utility_costs = pd.read_csv("../data/utility_technology_costs.csv", index_col='technology')
utility_costs *= 1e3
utility_costs.tail()
# Out:
#                                   Fixed O&M           OCC
# technology
# OffShoreWind                   98936.957353  2.149057e+06
# Pumped Storage Hydropower      18660.000000  3.215894e+06
# Utility-Scale Battery Storage  53840.076037  2.153603e+06
# Utility-Scale PV-Plus-Battery  57635.123527  1.906395e+06
# UtilityPV                      20483.036808  1.204175e+06

# %% [markdown]
# Step 7: Add generators to network

# %%
def annuity(r, n):
    return r / (1 - 1 / (1 + r)**n)

# %%
annuity_adj = annuity(0.07, 20)
annuity_adj
# Out:
# 0.09439292574325567

# %%
costs = costs.assign(annualized_cost = costs['OCC']*annuity_adj + costs['Fixed O&M'])
utility_costs = utility_costs.assign(annualized_cost = utility_costs['OCC']*annuity_adj + utility_costs['Fixed O&M'])
display(utility_costs.tail())
display(costs)
# Out:
#                                   Fixed O&M           OCC  annualized_cost
# technology
# OffShoreWind                   98936.957353  2.149057e+06    301792.765867
# Pumped Storage Hydropower      18660.000000  3.215894e+06    322217.636737
# Utility-Scale Battery Storage  53840.076037  2.153603e+06    257124.968010
# Utility-Scale PV-Plus-Battery  57635.123527  1.906395e+06    237585.318179
# UtilityPV                      20483.036808  1.204175e+06    134148.605782
#                                 Fixed O&M           OCC  annualized_cost
# technology
# DistributedWind              35912.100000  5.678577e+06    571929.570926
# ResPV                        28108.825392  2.630889e+06    276446.116985
# Residential Battery Storage  78943.789878  3.157752e+06    377013.201712

# %%
# residential generators
for generator in costs.index:
    if generator == 'DistributedWind':
        pass
    else:
        print(generator)
        annualized_cost = costs.at[generator, 'annualized_cost']
        print(annualized_cost)
        
        if generator=='ResPV':
            n.add(class_name='Generator',
                    name=generator,
                    bus=bus_name,
                    carrier="solar",
                    capital_cost=annualized_cost,  # $/kW
                    p_min_pu=ghi,
                    p_max_pu=ghi,
                    p_nom_extendable=True,
                    p_nom_max = 2.807,
                    )
        elif generator=='Residential Battery Storage':
            pass
            n.add(class_name="StorageUnit",
                    name=generator,
                    bus=bus_name,
                    carrier="battery",
                    capital_cost=annualized_cost,  # $/kW
                    p_nom_extendable=True,
                    max_hours=2.5,
                    cyclic_state_of_charge=False,
                    )
# Out:
# ResPV
# 276446.11698458303
# Residential Battery Storage
# 377013.20171200635

# %%
# community solar generator

n.add(class_name="Generator",
      name="Community Solar",
      bus="CommunitySolar",
      carrier="solar",
      capital_cost=utility_costs.at['UtilityPV','annualized_cost'],
    #   p_min_pu=ghi,
      p_max_pu=ghi,
      p_nom_extendable=True,
      p_nom_max=10
      )

# %% [markdown]
# Add a "net metering" technology to capture the excess energy.

# %%
retail_price = 112.9  # $/MWh

# %%
n.add(class_name="Generator",
      name=f"Net metering {bus_name}",
      bus=bus_name,
      carrier='net metering',
      p_min_pu=-1,
      p_max_pu=0.0,
      marginal_cost=retail_price*0.0,
      capital_cost=0.0,
      p_nom_extendable=True)

# %%
n.add(class_name='Generator',
      name='Evergy Import',
      bus=bus_name,
      carrier='grid',
      capital_cost=0,
      marginal_cost=retail_price,
      p_nom_extendable=True,
      # p_nom_max=1.3315
      )

# %%
n.generators
# Out:
# attribute                         bus control type  p_nom  p_nom_mod  \
# Generator
# ResPV                     Residential      PQ         0.0        0.0
# Net metering Residential  Residential      PQ         0.0        0.0
# Evergy Import             Residential      PQ         0.0        0.0
#
# attribute                 p_nom_extendable  p_nom_min  p_nom_max  p_min_pu  \
# Generator
# ResPV                                 True        0.0      2.807       0.0
# Net metering Residential              True        0.0        inf      -1.0
# Evergy Import                         True        0.0        inf       0.0
#
# attribute                 p_max_pu  ...  min_up_time  min_down_time  \
# Generator                           ...
# ResPV                          1.0  ...            0              0
# Net metering Residential       0.0  ...            0              0
# Evergy Import                  1.0  ...            0              0
#
# attribute                 up_time_before down_time_before  ramp_limit_up  \
# Generator
# ResPV                                  1                0            NaN
# Net metering Residential               1                0            NaN
# Evergy Import                          1                0            NaN
#
# attribute                 ramp_limit_down  ramp_limit_start_up  \
# Generator
# ResPV                                 NaN                  1.0
# Net metering Residential              NaN                  1.0
# Evergy Import                         NaN                  1.0
#
# attribute                 ramp_limit_shut_down  weight  p_nom_opt
# Generator
# ResPV                                      1.0     1.0        0.0
# Net metering Residential                   1.0     1.0        0.0
# Evergy Import                              1.0     1.0        0.0
#
# [3 rows x 34 columns]

# %% [markdown]
# ## Model Version: Baseline
#
# At this moment, the model
#
# * uses the sticker price for rooftop solar from NREL's ATB
# * does NOT pay for net metering
# * does NOT include residential storage

# %% [markdown]
# Step 6: Run the model

# %%
n.optimize(solver_name='highs')
# Out:
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 29.39it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 69.63it/s]
# INFO:linopy.io: Writing time: 0.58s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# ('ok', 'optimal')

# %%
results_1 = n.statistics().copy()
results_1
# Out:
# c:\Users\sdotson\AppData\Local\miniforge3\envs\kansas-city\lib\site-packages\pypsa\statistics.py:308: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#                 Optimal Capacity  Installed Capacity      Supply  Withdrawal  \
# Generator grid          1.430806                 0.0  4135.96535     0.00000
# Load      -             0.000000                 0.0     0.00000  4135.96535
#
#                   Dispatch  Transmission  Capacity Factor  Curtailment  \
# Generator grid  4135.96535           0.0         0.329983          0.0
# Load      -    -4135.96535           0.0              NaN          0.0
#
#                 Capital Expenditure  Operational Expenditure        Revenue  \
# Generator grid                  0.0            466950.487985  466950.487985
# Load      -                     0.0                 0.000000 -466950.487985
#
#                 Market Value
# Generator grid         112.9
# Load      -              NaN

# %%
n.storage_units.p_nom_opt
# Out:
# StorageUnit
# Residential Battery Storage   -0.0
# Name: p_nom_opt, dtype: float64

# %% [markdown]
# Step 7: Calculate the LCOE from the model

# %%
model_lcoe_1 = n.objective / n.loads_t.p_set.sum().values[0]
model_lcoe_1
# Out:
# 112.9000000000018

# %% [markdown]
# We observe that the model has an LCOE of $112.9/MWh, which makes sense because it only uses electricity purchased from the grid.

# %% [markdown]
# Step 8: Plot some data

# %%
fig, ax = plt.subplots()
time = '2018-07-08'
n.generators_t.p.loc[time:'2018-07-12'].plot.area(ax=ax, lw=0, legend=False)
n.loads_t.p_set.loc[time:'2018-07-12'].plot(ax=ax, color='k', legend=False)
# Out:
# <Axes: xlabel='snapshot'>

# %% [markdown]
# ## Model Version: Policy Simulation
#
# The purpose of this simulation is to test the effect of price reductions and net metering on solar penetration.

# %%
data = {'discount':[],
        'percent_retail_price':[],
        'solar_capacity':[],
        'battery_capacity':[],
        'objective_value':[],
        }


delta = 0.02
discounts = np.arange(0, 1+delta, delta)
retail_prices = np.linspace(0, 1, 5)
for discount in discounts:
    for pct_retail in retail_prices:
        n.generators.loc['ResPV', 'capital_cost'] = costs.at['ResPV','annualized_cost'] * (1-discount)
        n.generators.loc['Net metering Residential', 'marginal_cost'] = retail_price*pct_retail
        n.optimize(solver_name='highs')
        
        data['discount'].append(discount)
        data['solar_capacity'].append(np.abs(n.generators.p_nom_opt['ResPV']))
        data['battery_capacity'].append(np.abs(n.storage_units.p_nom_opt['Residential Battery Storage']))
        data['percent_retail_price'].append(pct_retail)
        data['objective_value'].append(n.objective)
# Out:
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.11it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 54.69it/s]
# INFO:linopy.io: Writing time: 0.87s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 16.91it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 48.08it/s]
# INFO:linopy.io: Writing time: 1.0s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 15.77it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 45.49it/s]
# INFO:linopy.io: Writing time: 1.07s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:01<00:00,  8.08it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 45.13it/s]
# INFO:linopy.io: Writing time: 1.94s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:01<00:00, 12.84it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 39.93it/s]
# INFO:linopy.io: Writing time: 1.3s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 17.70it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 49.42it/s]
# INFO:linopy.io: Writing time: 0.95s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:01<00:00,  9.32it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 22.95it/s]
# INFO:linopy.io: Writing time: 1.86s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 16.09it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 66.44it/s]
# INFO:linopy.io: Writing time: 1.01s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 17.93it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 49.91it/s]
# INFO:linopy.io: Writing time: 0.95s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.58it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 53.96it/s]
# INFO:linopy.io: Writing time: 0.86s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 20.00it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 55.44it/s]
# INFO:linopy.io: Writing time: 0.84s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.61it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 48.11it/s]
# INFO:linopy.io: Writing time: 0.9s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.30it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 50.11it/s]
# INFO:linopy.io: Writing time: 0.89s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.76it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 65.83it/s]
# INFO:linopy.io: Writing time: 0.86s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.65it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 53.75it/s]
# INFO:linopy.io: Writing time: 0.87s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 20.30it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 42.44it/s]
# INFO:linopy.io: Writing time: 0.86s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.19it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 53.67it/s]
# INFO:linopy.io: Writing time: 0.9s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 20.01it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 66.02it/s]
# INFO:linopy.io: Writing time: 0.85s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 18.72it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 50.29it/s]
# INFO:linopy.io: Writing time: 0.91s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.36it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 73.19it/s]
# INFO:linopy.io: Writing time: 0.87s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 21.82it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 66.59it/s]
# INFO:linopy.io: Writing time: 0.77s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.36it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 66.75it/s]
# INFO:linopy.io: Writing time: 0.87s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.48it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 48.43it/s]
# INFO:linopy.io: Writing time: 0.89s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.54it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 55.59it/s]
# INFO:linopy.io: Writing time: 0.87s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.35it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 50.90it/s]
# INFO:linopy.io: Writing time: 0.89s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 18.26it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 53.90it/s]
# INFO:linopy.io: Writing time: 0.92s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 18.88it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 53.98it/s]
# INFO:linopy.io: Writing time: 0.91s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:01<00:00,  8.67it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 22.34it/s]
# INFO:linopy.io: Writing time: 2.03s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:01<00:00,  9.33it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 24.89it/s]
# INFO:linopy.io: Writing time: 1.85s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:01<00:00,  8.02it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 26.04it/s]
# INFO:linopy.io: Writing time: 2.11s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:01<00:00,  8.43it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 18.77it/s]
# INFO:linopy.io: Writing time: 2.04s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 17.76it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 54.51it/s]
# INFO:linopy.io: Writing time: 0.96s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.22it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 54.53it/s]
# INFO:linopy.io: Writing time: 0.88s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.49it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 54.01it/s]
# INFO:linopy.io: Writing time: 0.89s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.68it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 51.95it/s]
# INFO:linopy.io: Writing time: 0.88s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.47it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 53.27it/s]
# INFO:linopy.io: Writing time: 0.86s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.19it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 54.72it/s]
# INFO:linopy.io: Writing time: 0.89s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 23.73it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 62.19it/s]
# INFO:linopy.io: Writing time: 0.72s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 22.42it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 60.80it/s]
# INFO:linopy.io: Writing time: 0.76s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 21.84it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 60.79it/s]
# INFO:linopy.io: Writing time: 0.79s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 26.21it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 65.98it/s]
# INFO:linopy.io: Writing time: 0.65s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 22.30it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 59.04it/s]
# INFO:linopy.io: Writing time: 0.76s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 22.55it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 60.93it/s]
# INFO:linopy.io: Writing time: 0.75s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 21.22it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 73.89it/s]
# INFO:linopy.io: Writing time: 0.78s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 21.22it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 53.13it/s]
# INFO:linopy.io: Writing time: 0.82s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 21.54it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 60.18it/s]
# INFO:linopy.io: Writing time: 0.78s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 22.68it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 60.25it/s]
# INFO:linopy.io: Writing time: 0.75s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 22.47it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 68.73it/s]
# INFO:linopy.io: Writing time: 0.76s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 21.99it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 67.66it/s]
# INFO:linopy.io: Writing time: 0.75s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 19.99it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 50.34it/s]
# INFO:linopy.io: Writing time: 0.87s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 22.17it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 50.79it/s]
# INFO:linopy.io: Writing time: 0.77s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 23.72it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 58.34it/s]
# INFO:linopy.io: Writing time: 0.72s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# ...
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 15.90it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 26.54it/s]
# INFO:linopy.io: Writing time: 1.17s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 1.13e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 14.64it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 32.46it/s]
# INFO:linopy.io: Writing time: 1.23s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.66e+04
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 16.41it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 43.56it/s]
# INFO:linopy.io: Writing time: 1.04s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 2.97e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:01<00:00, 13.76it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 27.00it/s]
# INFO:linopy.io: Writing time: 1.31s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 2.31e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:01<00:00, 13.20it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 40.13it/s]
# INFO:linopy.io: Writing time: 1.29s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 1.64e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 15.61it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 46.95it/s]
# INFO:linopy.io: Writing time: 1.08s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 9.77e+04
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 16.06it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 45.33it/s]
# INFO:linopy.io: Writing time: 1.06s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 3.11e+04
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:01<00:00, 12.32it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 38.45it/s]
# INFO:linopy.io: Writing time: 1.34s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 2.82e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 15.43it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 29.35it/s]
# INFO:linopy.io: Writing time: 1.17s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 2.15e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 16.14it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 45.59it/s]
# INFO:linopy.io: Writing time: 1.05s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 1.49e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 16.15it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 46.72it/s]
# INFO:linopy.io: Writing time: 1.05s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 8.21e+04
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 15.86it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 45.38it/s]
# INFO:linopy.io: Writing time: 1.07s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 1.56e+04
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 14.92it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 44.08it/s]
# INFO:linopy.io: Writing time: 1.12s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 2.66e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 16.01it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 44.98it/s]
# INFO:linopy.io: Writing time: 1.06s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 2.00e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 17.16it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 39.12it/s]
# INFO:linopy.io: Writing time: 1.03s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 1.33e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 16.67it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 40.93it/s]
# INFO:linopy.io: Writing time: 1.04s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 6.66e+04
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 15.90it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 45.98it/s]
# INFO:linopy.io: Writing time: 1.06s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 6.61e+01
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.

# %%
results_df_large = pd.DataFrame(data)
results_df_large
# Out:
#      discount  percent_retail_price  solar_capacity  battery_capacity  \
# 0         0.0                  0.00           0.000               0.0
# 1         0.0                  0.25           0.000               0.0
# 2         0.0                  0.50           0.000               0.0
# 3         0.0                  0.75           0.000               0.0
# 4         0.0                  1.00           0.000               0.0
# ..        ...                   ...             ...               ...
# 250       1.0                  0.00           2.807               0.0
# 251       1.0                  0.25           2.807               0.0
# 252       1.0                  0.50           2.807               0.0
# 253       1.0                  0.75           2.807               0.0
# 254       1.0                  1.00           2.807               0.0
#
#      objective_value
# 0      466950.487985
# 1      466950.487985
# 2      466950.487985
# 3      466950.487985
# 4      466950.487985
# ..               ...
# 250    266273.015698
# 251    199721.286719
# 252    133169.557739
# 253     66617.828760
# 254        66.099781
#
# [255 rows x 5 columns]

# %%
import seaborn as sb

# %%
results_df_large = results_df_large.assign(solar_penetration=results_df_large['solar_capacity'] / n.generators.p_nom_max.ResPV)

# %%
results_df_large = pd.read_csv('simulation_data.csv', index_col=0)

# %%
fig, ax = plt.subplots()
sb.lineplot(data=results_df_large[['discount','solar_penetration','percent_retail_price']]*100,
            x='discount',
            y='solar_penetration',
            ax=ax,
            hue='percent_retail_price',
            palette='viridis')

ax.set_ylabel("% of total electricity covered by solar")
ax.set_xlabel("Reduction in Capital Cost\n (%)")
ax.legend(title='Net Metering Price\n (% Retail Price)')

ax.minorticks_on()
ax.grid(which='major')
ax.grid(which='minor', alpha=0.2)
ax.set_ylim(0,1.05*100)
ax.set_xlim(0,1.0*100)

ax.axvline(x=50, color='tab:red', linestyle='--')

# %%
results_df_large['solar_penetration'] = results_df_large['solar_penetration'].round(2)

# %%
ax = results_df_large.loc[results_df_large['discount']==0.5, ['percent_retail_price','solar_penetration']].plot.bar(x='percent_retail_price',
                                                                                                               y='solar_penetration',
                                                                                                               legend=False,
                                                                                                               zorder=3,
                                                                                                               color='gold')
ax.set_xlabel('Net Metering Price \n (fraction of retail price)')
ax.set_ylabel("Solar penetration \n (fraction)")
ax.set_title("Solar potential with 50% Tax Credits")

ax.minorticks_on()
ax.grid(which='major', zorder=0)
ax.grid(which='minor', alpha=0.2)

ax.patches[0].set_edgecolor('red')
ax.patches[0].set_linewidth(3)
ax.bar_label(ax.containers[0])
plt.show()

# %%
results_df_large.describe()
# Out:
#          discount  percent_retail_price  solar_capacity  battery_capacity  \
# count  255.000000            255.000000      255.000000             255.0
# mean     0.500000              0.500000        1.217456               0.0
# std      0.294971              0.354249        1.236635               0.0
# min      0.000000              0.000000        0.000000               0.0
# 25%      0.240000              0.250000        0.000000               0.0
# 50%      0.500000              0.500000        0.757254               0.0
# 75%      0.760000              0.750000        2.807000               0.0
# max      1.000000              1.000000        2.807000               0.0
#
#        objective_value  solar_penetration
# count       255.000000         255.000000
# mean     382392.224079           0.433721
# std      117536.626041           0.440554
# min          66.099781           0.000000
# 25%      324929.125859           0.000000
# 50%      448625.587086           0.269774
# 75%      466950.487985           1.000000
# max      466950.487985           1.000000

# %%
results_df_large = results_df_large.assign(lcoe=results_df_large['objective_value'] / n.loads_t.p_set.sum().values[0] / 1000)

# %%
fig, ax = plt.subplots()
sb.lineplot(data=results_df_large,
            x='discount',
            y='lcoe',
            ax=ax,
            hue='percent_retail_price',
            palette='viridis'
            )

ax.set_ylabel("Retail Price of Electricity \n ($ / kWh)")
ax.set_xlabel("Reduction in Capital Cost \n (%)")
ax.legend(title='Net Metering Price\n (% Retail Price)')

ax.minorticks_on()
ax.grid(which='major')
ax.grid(which='minor', alpha=0.2)
# ax.set_ylim(0,1.005)
ax.set_xlim(0,1.0)
# Out:
# (0.0, 1.0)

# %% [markdown]
# results_df_large.to_csv("simulation_data.csv")

# %%
(costs.at['ResPV','annualized_cost'] * 2.807) / load_resampled.sum()
# Out:
# 0.18761865362970692

# %% [markdown]
# ## Model Version: Net Metering
#
# At this moment, the model
#
# * uses the sticker price for rooftop solar from NREL's ATB
# * applies 100% retail price for net metering
# * does NOT include residential storage

# %%
n.generators.loc['Net metering Residential', 'marginal_cost'] = retail_price*1.0

# %%
n.optimize(solver_name='highs')
# Out:
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 28.82it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 71.10it/s]
# INFO:linopy.io: Writing time: 0.62s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.67e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# ('ok', 'optimal')

# %%
n.statistics()
# Out:
# c:\Users\sdotson\AppData\Local\miniforge3\envs\kansas-city\lib\site-packages\pypsa\statistics.py:308: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#                 Optimal Capacity  Installed Capacity      Supply  Withdrawal  \
# Generator grid          1.430806                 0.0  4135.96535     0.00000
# Load      -             0.000000                 0.0     0.00000  4135.96535
#
#                   Dispatch  Transmission  Capacity Factor  Curtailment  \
# Generator grid  4135.96535           0.0         0.329983          0.0
# Load      -    -4135.96535           0.0              NaN          0.0
#
#                 Capital Expenditure  Operational Expenditure        Revenue  \
# Generator grid                  0.0            466950.487985  466950.487985
# Load      -                     0.0                 0.000000 -466950.487985
#
#                 Market Value
# Generator grid         112.9
# Load      -              NaN

# %%
model_lcoe_2 = n.objective / n.loads_t.p_set.sum()
model_lcoe_2
# Out:
# Load
# Load Residential    112.9
# dtype: float64

# %%
fig, ax = plt.subplots()
time = '2018-07-08'
n.generators_t.p.loc[time:'2018-07-12'].plot.area(ax=ax, lw=0, legend=False)
n.loads_t.p_set.loc[time:'2018-07-12'].plot(ax=ax, color='k', legend=False)
# Out:
# <Axes: xlabel='snapshot'>

# %% [markdown]
# ## Model Version: Tax Credits
#
# At this moment, the model
#
# * reduces the price for rooftop solar by applying federal tax credits.
# * does NOT pay for net metering
# * does NOT include residential storage
#
# Apply the Residential Renewable Energy Tax Credit
#
# [DSIRE Data on the RRETC](https://programs.dsireusa.org/system/program/detail/1235/residential-renewable-energy-tax-credit) -- solar and storage each get a 30% tax credit.
#
# Apply the Investment Tax Credit (ITC)
#
# [EPA Data on ITC](https://www.epa.gov/green-power-markets/summary-inflation-reduction-act-provisions-related-renewable-energy) -- qualified residential units in a low-income area recieve +20%.
#
# [Homeowner's Guide to Federal Tax Credits](https://www.energy.gov/eere/solar/homeowners-guide-federal-tax-credit-solar-photovoltaics).
#
# This will be implemented as a direct 50% cost reduction.

# %%
# reset the price of net metering
n.generators.loc['Net metering Residential', 'marginal_cost'] = retail_price*0.0

# %%
rretc_credit = 0.5

# %%
n.storage_units
# Out:
# attribute                            bus control type  p_nom  p_nom_mod  \
# StorageUnit
# Residential Battery Storage  Residential      PQ         0.0        0.0
#
# attribute                    p_nom_extendable  p_nom_min  p_nom_max  p_min_pu  \
# StorageUnit
# Residential Battery Storage              True        0.0        inf      -1.0
#
# attribute                    p_max_pu  ...  \
# StorageUnit                            ...
# Residential Battery Storage       1.0  ...
#
# attribute                    state_of_charge_initial_per_period  \
# StorageUnit
# Residential Battery Storage                               False
#
# attribute                    state_of_charge_set  cyclic_state_of_charge  \
# StorageUnit
# Residential Battery Storage                  NaN                   False
#
# attribute                   cyclic_state_of_charge_per_period  max_hours  \
# StorageUnit
# Residential Battery Storage                              True        2.5
#
# attribute                    efficiency_store  efficiency_dispatch  \
# StorageUnit
# Residential Battery Storage               1.0                  1.0
#
# attribute                    standing_loss  inflow  p_nom_opt
# StorageUnit
# Residential Battery Storage            0.0     0.0       -0.0
#
# [1 rows x 30 columns]

# %%
n.generators.loc['ResPV', 'capital_cost'] *= (1-rretc_credit)
n.storage_units.loc['Residential Battery Storage', 'capital_cost'] *= (1-rretc_credit)

# %%
n.optimize(solver_name='highs')
# Out:
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 23.35it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 73.29it/s]
# INFO:linopy.io: Writing time: 0.7s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 4.17e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# ('ok', 'optimal')

# %%
n.statistics()
# Out:
# c:\Users\sdotson\AppData\Local\miniforge3\envs\kansas-city\lib\site-packages\pypsa\statistics.py:308: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#                         Optimal Capacity  Installed Capacity       Supply  \
# Generator grid                  1.342852                 0.0  2964.049410
#           net metering          0.669086                 0.0     0.000000
#           solar                 0.947609                 0.0  1396.053259
# Load      -                     0.000000                 0.0     0.000000
#
#                         Withdrawal     Dispatch  Transmission  \
# Generator grid             0.00000  2964.049410           0.0
#           net metering   224.13732  -224.137320           0.0
#           solar            0.00000  1396.053259           0.0
# Load      -             4135.96535 -4135.965350           0.0
#
#                         Capacity Factor   Curtailment  Capital Expenditure  \
# Generator grid                 0.251973  0.000000e+00               0.0000
#           net metering         0.038241  0.000000e+00               0.0000
#           solar                0.168178  3.914040e-10           82394.7361
# Load      -                         NaN  0.000000e+00               0.0000
#
#                         Operational Expenditure        Revenue  Market Value
# Generator grid                    334641.178424  334641.178424    112.900000
#           net metering                 0.000000       0.000000      0.000000
#           solar                        0.000000   82394.736100     59.019766
# Load      -                            0.000000 -417035.914525           NaN

# %% [markdown]
# Calculate the LCOE

# %%
model_lcoe_3 = n.objective / n.loads_t.p_set.sum().values[0]
model_lcoe_3
# Out:
# 100.83157842499818

# %% [markdown]
# Calculate the electricity price reduction

# %%
np.abs((100.831578 - 112.9)/112.9)*100
# Out:
# 10.689479185119586

# %% [markdown]
# Looks like almost a 10.7% reduction in electricity cost.

# %%
fig, ax = plt.subplots()
time = '2018-07-08'
n.generators_t.p.loc[time:'2018-07-12'].plot.area(ax=ax, lw=0, legend=False)
n.loads_t.p_set.loc[time:'2018-07-12'].plot(ax=ax, color='k', legend=False)
# Out:
# <Axes: xlabel='snapshot'>

# %% [markdown]
# ## Model Version: Net Metering + Tax Credits
#
# At this moment, the model
#
# * reduces the price for rooftop solar by applying federal tax credits.
# * Applies 50% retail price for net metering
# * does NOT include residential storage

# %%
n.generators.marginal_cost
# Out:
# Generator
# ResPV                         0.0
# Net metering Residential      0.0
# Evergy Import               112.9
# Name: marginal_cost, dtype: float64

# %%
n.generators.loc['Net metering Residential', 'marginal_cost'] = retail_price*0.5

# %%
n.generators.marginal_cost
# Out:
# Generator
# ResPV                         0.00
# Net metering Residential     56.45
# Evergy Import               112.90
# Name: marginal_cost, dtype: float64

# %%
n.optimize(solver_name='highs')
# Out:
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 24.79it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 60.33it/s]
# INFO:linopy.io: Writing time: 0.71s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 3.77e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# ('ok', 'optimal')

# %%
n.statistics()
# Out:
# c:\Users\sdotson\AppData\Local\miniforge3\envs\kansas-city\lib\site-packages\pypsa\statistics.py:308: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#                         Optimal Capacity  Installed Capacity       Supply  \
# Generator grid                  1.331491                 0.0  2358.485524
#           net metering          2.505756                 0.0     0.000000
#           solar                 2.807000                 0.0  4135.379878
# Load      -                     0.000000                 0.0     0.000000
#
#                          Withdrawal     Dispatch  Transmission  \
# Generator grid             0.000000  2358.485524           0.0
#           net metering  2357.900052 -2357.900052           0.0
#           solar            0.000000  4135.379878           0.0
# Load      -             4135.965350 -4135.965350           0.0
#
#                         Capacity Factor   Curtailment  Capital Expenditure  \
# Generator grid                 0.202205  0.000000e+00             0.000000
#           net metering         0.107419  0.000000e+00             0.000000
#           solar                0.168178  1.159408e-09        244069.150984
# Load      -                         NaN  0.000000e+00             0.000000
#
#                         Operational Expenditure        Revenue  Market Value
# Generator grid                    266273.015698  266273.015698    112.900000
#           net metering           -133103.457958 -133103.457958           NaN
#           solar                        0.000000  255898.612865     61.880316
# Load      -                            0.000000 -389068.170605           NaN

# %%
model_lcoe_4 = n.objective / n.loads_t.p_set.sum().values[0]
model_lcoe_4
# Out:
# 91.20934940819072

# %%
fig, ax = plt.subplots()
time = '2018-07-08'
n.generators_t.p.loc[time:'2018-07-12'].plot.area(ax=ax, lw=0, legend=False)
n.loads_t.p_set.loc[time:'2018-07-12'].plot(ax=ax, color='k', legend=False)
# Out:
# <Axes: xlabel='snapshot'>

# %% [markdown]
# ## Model Version: Net Metering + Tax Credits
#
# At this moment, the model
#
# * reduces the price for rooftop solar by applying federal tax credits.
# * Applies 99% retail price for net metering
# * does NOT include residential storage

# %%
n.generators.loc['Net metering Residential', 'marginal_cost'] = retail_price*1.00

# %%
n.generators.marginal_cost
# Out:
# Generator
# ResPV                         0.0
# Net metering Residential    112.9
# Evergy Import               112.9
# Name: marginal_cost, dtype: float64

# %%
n.generators.loc['ResPV', 'p_nom_max'] = 2.807

# %%
n.optimize(solver_name='highs')
# Out:
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 14/14 [00:00<00:00, 26.47it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 69.62it/s]
# INFO:linopy.io: Writing time: 0.63s
# INFO:linopy.solvers:Log file at C:\Users\sdotson\AppData\Local\Temp\highs.log
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 52564 primals, 122645 duals
# Objective: 2.44e+05
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# ('ok', 'optimal')

# %%
n.statistics()
# Out:
# c:\Users\sdotson\AppData\Local\miniforge3\envs\kansas-city\lib\site-packages\pypsa\statistics.py:308: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#                         Optimal Capacity  Installed Capacity       Supply  \
# Generator grid                  1.331491                 0.0  2358.485524
#           net metering          2.505756                 0.0     0.000000
#           solar                 2.807000                 0.0  4135.379878
# Load      -                     0.000000                 0.0     0.000000
#
#                          Withdrawal     Dispatch  Transmission  \
# Generator grid             0.000000  2358.485524           0.0
#           net metering  2357.900052 -2357.900052           0.0
#           solar            0.000000  4135.379878           0.0
# Load      -             4135.965350 -4135.965350           0.0
#
#                         Capacity Factor   Curtailment  Capital Expenditure  \
# Generator grid                 0.202205  0.000000e+00             0.000000
#           net metering         0.107419  0.000000e+00             0.000000
#           solar                0.168178  1.159408e-09        244069.150984
# Load      -                         NaN  0.000000e+00             0.000000
#
#                         Operational Expenditure        Revenue  Market Value
# Generator grid                    266273.015698  266273.015698         112.9
#           net metering           -266206.915917 -266206.915917           NaN
#           solar                        0.000000  466884.388204         112.9
# Load      -                            0.000000 -466950.487985           NaN

# %%
model_lcoe_5 = n.objective / n.loads_t.p_set.sum().values[0]
model_lcoe_5
# Out:
# 59.02739266934207

# %%
fig, ax = plt.subplots()
time = '2018-07-08'
n.generators_t.p.loc[time:'2018-07-12'].plot.area(ax=ax, lw=0, legend=False)
n.loads_t.p_set.loc[time:'2018-07-12'].plot(ax=ax, color='k', legend=False)
# Out:
# <Axes: xlabel='snapshot'>

# %% [markdown]
# ## Basic Analysis: How much solar capacity is required to meet 100% demand?

# %%
solar_100 = ghi / ghi.sum() * load_resampled.sum()

# %%
net_load = load_resampled - solar_100

# %%
solar_cap = solar_100.max()
solar_cap
# Out:
# 2.8073974047750987

# %%
total_unmet_load = net_load.where(net_load>0).sum()

# %%
total_unmet_load*retail_price
# Out:
# 266266.65710289485

# %%
discounts = np.linspace(0,1,20)
full_solar_cost_data = np.array([(costs.at['ResPV','annualized_cost'] * (1-discount) * solar_cap 
                                  + total_unmet_load*retail_price) 
                                 / load_resampled.sum() 
                                 for discount in discounts])

# %%
retail_price/1e3
# Out:
# 0.1129

# %%
fig, ax = plt.subplots()
y1 = ax.plot(discounts, full_solar_cost_data/1e3, label='100% Solar Power')
y2 = ax.axhline(y=retail_price/1e3, xmax=0.74, color='tab:red', linestyle='--', label='Retail Price')
y2 = ax.axvline(x=0.74, ymax=0.1129*2.5, linestyle=':', color='tab:purple', label='Subsidy needed to breakeven')
ax.set_xlim(0,1)
ax.set_ylabel("Levelized Cost of Electricity \n ($/kWh)")
ax.set_xlabel("Reduction in Capital Cost\n (%)")
ax.minorticks_on()
ax.grid(which='major')
ax.grid(which='minor',alpha=0.2)
ax.legend()

# %%
fig, ax = plt.subplots()
sb.lineplot(data=results_df_large,
            x='discount',
            y='lcoe',
            ax=ax,
            hue='percent_retail_price',
            palette='viridis'
            )

y1 = ax.plot(discounts, full_solar_cost_data/1000)
y2 = ax.axhline(y=retail_price/1000, xmax=0.74, color='tab:red', linestyle='--')

ax.set_ylabel("Retail Price of Electricity \n ($ / kWh)")
ax.set_xlabel("Reduction in Capital Cost \n (%)")
ax.legend(title='Net Metering Price\n (% Retail Price)')

ax.minorticks_on()
ax.grid(which='major')
ax.grid(which='minor', alpha=0.2)
# ax.set_ylim(0,1.005)
ax.set_xlim(0,1.0)
# Out:
# (0.0, 1.0)

# %%
lcoe_costs = full_solar_cost_data.copy()
lcoe_costs[lcoe_costs>=retail_price] = retail_price

# %%
fig, ax = plt.subplots()
sb.lineplot(data=results_df_large,
            x='discount',
            y='lcoe',
            ax=ax,
            hue='percent_retail_price',
            palette='viridis'
            )

y1 = ax.plot(discounts, lcoe_costs/1000)
y2 = ax.axhline(y=retail_price/1000, xmax=0.74, color='tab:red', linestyle='--')

ax.set_ylabel("Retail Price of Electricity \n ($ / kWh)")
ax.set_xlabel("Reduction in Capital Cost \n (%)")
ax.legend(title='Net Metering Price\n (% Retail Price)')

ax.minorticks_on()
ax.grid(which='major')
ax.grid(which='minor', alpha=0.2)
# ax.set_ylim(0,1.005)
ax.set_xlim(0,1.0)
# Out:
# (0.0, 1.0)

# %%
((lcoe_costs/1000) - results_df_large.loc[results_df_large['percent_retail_price']==0].lcoe.values).sum()*100
# Out:
# 6.660796450820109

# %%
fig, ax = plt.subplots()
y1 = ax.plot(discounts, full_solar_cost_data)
y2 = ax.axhline(y=retail_price, xmax=0.74, color='tab:red', linestyle='--')
ax.set_xlim(0,1)
# Out:
# (0.0, 1.0)

# %%
costs.at['ResPV', 'annualized_cost'] * 2.807 * 20 / 1e6
# Out:
# 15.51968500751449

# %%
costs.at['ResPV', 'OCC'] * 2.807 /  1e6
# Out:
# 7.384904875130196
