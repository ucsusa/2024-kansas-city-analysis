# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp

# %%
community_solar_cost = 1744.25  # $/kW
rooftop_solar_cost = 2519  # $/MW
needed_capacity = 3.00  # MW

comm_sol_capacity = np.arange(0, needed_capacity, 20)
roof_sol_capacity = np.arange(0, needed_capacity, 20)

# %%
x2_intercept = (0 ,community_solar_cost*needed_capacity)
x1_intercept = (rooftop_solar_cost*needed_capacity, 0)

# %%
fig, ax = plt.subplots()
ax.axline(xy1=x1_intercept, xy2=x2_intercept)
