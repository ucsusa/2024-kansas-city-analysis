# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pygwalker as pyg
import seaborn as sb

# %%
results = pd.read_csv('../results/full_sensitivity_data.csv', index_col=0)

# %%
sb.pairplot(results[results['solar_penetration']<=1],corner=True)

# %%
results.loc[results['rooftop_capacity']<3, 'rooftop_capacity'].max()
# Out:
# 1.7970599201679742

# %%
pyg.walk(results[results['solar_penetration']<=1])
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00062c60b789d120x1prgAXamTMqdFG7" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00062c60b789d120x1prgAXamTMqdFG7") {
#             var iframe = document.getElementById("gwalker-00062c60b789d120x1prgAXamTMqdFG7");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
